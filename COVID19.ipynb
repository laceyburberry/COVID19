# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
print('Modules are imported.')
# Out:
# Modules are imported.

# %%
##Updated dataset can be downloaded from Johns Hopkins GitHub: https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data

# %%
JHU_dataset_global = pd.read_csv("C:/Users/Lacey/Desktop/time_series_covid19_confirmed_global.csv")
JHU_dataset_US = pd.read_csv("C:/Users/Lacey/Desktop/time_series_covid19_confirmed_US.csv")
JHU_dataset.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  9/11/20  9/12/20  9/13/20  \
# 0        0        0        0        0  ...    38606    38641    38716
# 1        0        0        0        0  ...    11021    11185    11353
# 2        0        0        0        0  ...    47752    48007    48254
# 3        0        0        0        0  ...     1344     1344     1344
# 4        0        0        0        0  ...     3279     3335     3388
#
#    9/14/20  9/15/20  9/16/20  9/17/20  9/18/20  9/19/20  9/20/20
# ...

# %%
print("JHU_dataset_global")
print(JHU_dataset_global.shape)
print("JHU_dataset_US")
print(JHU_dataset_US.shape)
# Out:
# JHU_dataset_global
# (266, 247)
# JHU_dataset_US
# (3340, 254)

# %%
cglobal = JHU_dataset_global.drop(["Lat", "Long"],axis=1) 
cUS = JHU_dataset_US.drop(["code3", "UID", "iso2", "iso3", "FIPS", "Admin2", "Lat", "Long_"],axis=1)

# %%
cglobal
# Out:
#     Province/State      Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0              NaN         Afghanistan        0        0        0        0
# 1              NaN             Albania        0        0        0        0
# 2              NaN             Algeria        0        0        0        0
# 3              NaN             Andorra        0        0        0        0
# 4              NaN              Angola        0        0        0        0
# ..             ...                 ...      ...      ...      ...      ...
# 261            NaN  West Bank and Gaza        0        0        0        0
# 262            NaN      Western Sahara        0        0        0        0
# 263            NaN               Yemen        0        0        0        0
# 264            NaN              Zambia        0        0        0        0
# 265            NaN            Zimbabwe        0        0        0        0
#
# ...

# %%
cUS
# Out:
#      Province_State Country_Region             Combined_Key  1/22/20  1/23/20  \
# 0           Alabama             US     Autauga, Alabama, US        0        0
# 1           Alabama             US     Baldwin, Alabama, US        0        0
# 2           Alabama             US     Barbour, Alabama, US        0        0
# 3           Alabama             US        Bibb, Alabama, US        0        0
# 4           Alabama             US      Blount, Alabama, US        0        0
# ...             ...            ...                      ...      ...      ...
# 3335        Wyoming             US       Teton, Wyoming, US        0        0
# 3336        Wyoming             US       Uinta, Wyoming, US        0        0
# 3337        Wyoming             US  Unassigned, Wyoming, US        0        0
# 3338        Wyoming             US    Washakie, Wyoming, US        0        0
# 3339        Wyoming             US      Weston, Wyoming, US        0        0
#
# ...

# %%
cglobal_aggregated = cglobal.groupby("Country/Region").sum()

# %%
cglobal_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  9/11/20  9/12/20  9/13/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...    38606    38641    38716
# Albania               0        0        0  ...    11021    11185    11353
# Algeria               0        0        0  ...    47752    48007    48254
# Andorra               0        0        0  ...     1344     1344     1344
# ...

# %%
cglobal_aggregated.loc["China"].plot()
cglobal_aggregated.loc["Italy"].plot()
cglobal_aggregated.loc["Spain"].plot()

plt.legend()

# %%
countries = list(cglobal_aggregated.index)
max_infection_rates = []  
for c in countries :     
    max_infection_rates.append(cglobal_aggregated.loc[c].diff().max())

max_infection_rates
# Out:
# [915.0,
#  178.0,
#  675.0,
#  94.0,
#  130.0,
#  39.0,
#  12701.0,
#  771.0,
#  716.0,
#  1321.0,
#  590.0,
#  136.0,
#  841.0,
#  4019.0,
#  12.0,
#  973.0,
#  2454.0,
#  113.0,
#  139.0,
#  29.0,
#  2036.0,
#  811.0,
#  278.0,
#  69074.0,
#  26.0,
#  350.0,
#  193.0,
#  642.0,
#  78.0,
#  114.0,
#  31.0,
#  2324.0,
#  2778.0,
#  216.0,
#  83.0,
#  13990.0,
#  15136.0,
#  15318.0,
#  44.0,
#  649.0,
#  414.0,
#  1907.0,
#  430.0,
#  369.0,
#  93.0,
#  58.0,
#  3123.0,
#  823.0,
#  99.0,
#  280.0,
#  5.0,
#  2147.0,
#  11536.0,
#  1774.0,
#  449.0,
#  1750.0,
#  31.0,
#  134.0,
#  147.0,
#  1829.0,
#  5.0,
#  267.0,
#  26849.0,
#  570.0,
#  248.0,
#  196.0,
#  6933.0,
#  1513.0,
#  372.0,
#  6.0,
#  4233.0,
#  278.0,
#  156.0,
#  101.0,
#  332.0,
#  3.0,
#  1141.0,
#  1070.0,
#  99.0,
#  97894.0,
#  4168.0,
#  3574.0,
#  5036.0,
#  1515.0,
#  6063.0,
#  6557.0,
#  244.0,
#  1762.0,
#  279.0,
#  18757.0,
#  960.0,
#  851.0,
#  695.0,
#  1073.0,
#  11505.0,
#  3.0,
#  48.0,
# ...

# %%
cglobal_aggregated["max_infection_rate"] = max_infection_rates

# %%
corona_data = pd.DataFrame(cglobal_aggregated["max_infection_rate"])

# %%
corona_data.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                  915.0
# Albania                      178.0
# Algeria                      675.0
# Andorra                       94.0
# Angola                       130.0

# %%
happiness_report_csv = pd.read_csv("C:/Users/Lacey/Desktop/World_Happiness_Report_2019.csv")

# %%
happiness_report_csv.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
useless_cols = ["Overall rank","Score","Generosity","Perceptions of corruption"]

# %%
happiness_report_csv.drop(useless_cols, axis=1, inplace=True)
happiness_report_csv.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
happiness_report_csv.set_index("Country or region",inplace=True)

# %%
happiness_report_csv.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
corona_data.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                  915.0
# Albania                      178.0
# Algeria                      675.0
# Andorra                       94.0
# Angola                       130.0

# %%
corona_data.shape
# Out:
# (188, 1)

# %%
happiness_report_csv.shape
# Out:
# (156, 4)

# %%
data = corona_data.join(happiness_report_csv,how="inner")
data.head()
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan               915.0           0.350           0.517
# Albania                   178.0           0.947           0.848
# Algeria                   675.0           1.002           1.160
# Argentina               12701.0           1.092           1.432
# Armenia                   771.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %%
data.corr()
# Out:
#                               max_infection_rate  GDP per capita  \
# max_infection_rate                      1.000000        0.090624
# GDP per capita                          0.090624        1.000000
# Social support                          0.042815        0.757521
# Healthy life expectancy                 0.083543        0.859431
# Freedom to make life choices            0.082367        0.394799
#
#                               Social support  Healthy life expectancy  \
# max_infection_rate                  0.042815                 0.083543
# GDP per capita                      0.757521                 0.859431
# Social support                      1.000000                 0.751632
# Healthy life expectancy             0.751632                 1.000000
# Freedom to make life choices        0.456317                 0.423146
#
#                               Freedom to make life choices
# max_infection_rate                                0.082367
# ...

# %%
data.head()
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan               915.0           0.350           0.517
# Albania                   178.0           0.947           0.848
# Algeria                   675.0           1.002           1.160
# Argentina               12701.0           1.092           1.432
# Armenia                   771.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %%
##Plotting GDP vs maximum Infection rate

# %%
x = data["GDP per capita"]
y = data["max_infection_rate"]
sns.scatterplot(x,y)
# Out:
# C:\Users\Lacey\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x = data["GDP per capita"]
y = data["max_infection_rate"]
sns.scatterplot(x, np.log(y))
# Out:
# C:\Users\Lacey\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.regplot(x, np.log(y))
# Out:
# C:\Users\Lacey\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x = data["Social support"]
y = data["max_infection_rate"]
sns.scatterplot(x, np.log(y))
# Out:
# C:\Users\Lacey\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.regplot(x, np.log(y))
# Out:
# C:\Users\Lacey\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x = data["Healthy life expectancy"]
y = data["max_infection_rate"]
sns.scatterplot(x, np.log(y))
# Out:
# C:\Users\Lacey\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.regplot(x, np.log(y))
# Out:
# C:\Users\Lacey\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x = data["Freedom to make life choices"]
y = data["max_infection_rate"]
sns.scatterplot(x, np.log(y))
# Out:
# C:\Users\Lacey\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.regplot(x, np.log(y))
# Out:
# C:\Users\Lacey\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
